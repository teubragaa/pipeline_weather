# %%
path = '../data/weather_data.json'

import pandas as pd
import json

# %%
with open(path) as f:
    data = json.load(f)

    df = pd.json_normalize(data, record_path=['data'], meta=['city', 'state', 'country', 'latitude', 'longitude', 'timezone'])
