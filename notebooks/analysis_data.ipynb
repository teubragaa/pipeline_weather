# %%
path = '../data/weather_data.json'

import pandas as pd
import json

# %%
with open(path) as f:
    data = json.load(f)

df = pd.json_normalize(data)
df.head()
# Out:
#                                              weather      base  visibility  \
# 0  [{'id': 800, 'main': 'Clear', 'description': '...  stations       10000
#
#            dt  timezone       id      name  cod  coord.lon  coord.lat  ...  \
# 0  1785719286    -10800  3450554  Salvador  200   -38.5108   -12.9711  ...
#
#    main.humidity  main.sea_level  main.grnd_level  wind.speed  wind.deg  \
# 0             66            1019             1019        6.26       105
#
#    wind.gust  clouds.all  sys.country  sys.sunrise  sys.sunset
# 0       7.34           2           BR   1785660815  1785702415
#
# [1 rows x 25 columns]
